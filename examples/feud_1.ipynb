# %%
import abcEconomics as abce

# %%
from inu.param.treeform import ParTree

# %%
ParTree(
    
    
)

# %%
class Person:
    def __init__(sex, age=0):
        assert sex in ('Male', 'Female')
        assert 0 <= age <= 120
        self.sex = sex
        self.age - age
        self.strength = 
        self.experience
        
    def aging(self, period=1):
        

class PeasantHousehold(abce.Agent, abce.Household):
    def init(name, goods=1, adults=2, store=0, labor_endow=360):
        adults = int(adults)
        assert adults > 0
        self.adults = self.create('PeasantAdults', adults)
        self.name = f'peasant {self.id}'
        self.labor_endow
        self.goods = goods
    
    def reproduce(self, period=1):
        """
        Reproduction (includes also dying) of the peasants household
        """

# %%
sim = abce.Simulation('test1', trade_logging='individual')

# %%
sim
# Out:
# ['c:\\Work\\code\\extools\\abce\\examples',
#  'C:\\Users\\ilyap\\anaconda3\\envs\\abc\\python37.zip',
#  'C:\\Users\\ilyap\\anaconda3\\envs\\abc\\DLLs',
#  'C:\\Users\\ilyap\\anaconda3\\envs\\abc\\lib',
#  'C:\\Users\\ilyap\\anaconda3\\envs\\abc',
#  '',
#  'C:\\Users\\ilyap\\AppData\\Roaming\\Python\\Python37\\site-packages',
#  'C:\\Users\\ilyap\\anaconda3\\envs\\abc\\lib\\site-packages',
#  'C:\\Users\\ilyap\\anaconda3\\envs\\abc\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\ilyap\\.ipython']

# %%
ps = sim.build_agents(Peasant, 'peasants', 1, )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3d22edca90c7> in <module>
# ----> 1 ps = sim.build_agents(Peasant, 'peasants', 1, )
#
# NameError: name 'sim' is not defined

# %%
sim.sim_parameters
# Out:
# OrderedDict([('name', 'test1'),
#              ('random_seed', 1566066091.8419998),
#              ('peasants', {})])

# %%
def capability(peak_age=20, aging_rate=1):
    # compress aging rate into (0.4, 2.1) range assymetrically centered around (1,1)
    aging_rate = ((tanh(aging_rate-1)+1)**1.2-1)*.9+1
    
    up_rate=peak_age/pi
    down_rate = peak_age/pi*3/aging_rate
    
    norm = 1
    def func(x):
        up = (tanh((-peak_age/2 + x)/up_rate)+1)/2
        down = (tanh((peak_age*(4-aging_rate*1.2) - x)/down_rate)+1)/2
        return up * down * norm 
    
    samples = linspace(peak_age-up_rate/3, peak_age+down_rate/3, 10)
    norm = (1-0.00001)/amax(func(samples))
    return func


plt_max = 120
plt_step = 10
plt_rng = arange(plt_max)

f1 = capability()
f2 = capability(peak_age=30)
f3 = capability(peak_age=30, aging_rate=4)

fig = figure(figsize=(10,4))

plot(f1(plt_rng), label='1')
plot(f2(plt_rng), label='2')
pl3, = plot(f3(plt_rng), label='3')

legend()
xticks(range(0, plt_max + plt_step, plt_step))
xlim(0,plt_max)
yticks(arange(0, 1.1, 0.1))
ylim(0,1.1)
tight_layout(pad=0.5)

@interact
def update(peak=20., aging=1.):
    f = capability(peak_age=peak, aging_rate=aging)
    pl3.set_ydata(f(plt_rng))
    fig.canvas.draw_idle()
# Out:
# <img src="data:image/png;base64,..." width="949.6">
# interactive(children=(FloatSlider(value=20.0, description='peak', max=60.0, min=-20.0), FloatSlider(value=1.0,…

# %%
def lookup(xp, yp, left=None, right=None):
    from numpy import interp
    def func(x):
        return interp(x, xp, yp, left=left, right=right)
    return func

# %%
f = lookup([0, 10, 20, 40], [0,1,1,0])

x = arange(-20, 45, 0.1)
figure();
plot(x, f(x))

# %%
import graphviz as gv

# %%
# %%writefile test.dot
# digraph graphname {
#      a -> b -> c;
#      b -> d;
#  }
# Out:
# Overwriting test.dot

# %%
gv.Source("""digraph graphname {
    a -> b -> c;
    b -> {d s};
}""")

# %%
gv.Source.from_file('test.dot')

# %%
G

# %%
.draw('test.png', prog='dot')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-b5d852a4e2c5> in <module>
# ----> 1 gv.AGraph('test.dot').draw('test.png', prog='dot')
#
# ~\anaconda3\envs\abc\lib\site-packages\pygraphviz\agraph.py in draw(self, path, format, prog, args)
#    1513             args = ' '.join([args, "-T" + format])
#    1514
# -> 1515         data = self._run_prog(prog, args)
#    1516
#    1517         if path is not None:
#
# ~\anaconda3\envs\abc\lib\site-packages\pygraphviz\agraph.py in _run_prog(self, prog, args)
#    1362
#    1363         if not data:
# -> 1364             raise IOError(b"".join(errors).decode(self.encoding))
#    1365
#    1366         if len(errors) > 0:
#
# OSError: Format: "png" not recognized. Use one of:

# %%
gv.AGraph.write()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2195e77a5624> in <module>
# ----> 1 gv.AGraph.draw()
#
# TypeError: draw() missing 1 required positional argument: 'self'
